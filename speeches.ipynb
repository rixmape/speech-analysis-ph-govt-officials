# %%
import json
import requests
from bs4 import BeautifulSoup

# %%
def get_soup(link):
    """Returns a BeautifulSoup object of the given link"""
    try:
        response = requests.get(link)
        response.raise_for_status()  # Raises stored HTTPError, if one occurred.
    except requests.HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')
        return None
    except Exception as err:
        print(f'Other error occurred: {err}')
        return None
    else:
        return BeautifulSoup(response.text, 'html.parser')

# %%
page_link = "https://www.ovp.gov.ph/category/1/vp-sara-speeches"
speeches = []
page_count = 1

while page_link:
    print(f"Scraping page {page_count}...")
    page_soup = get_soup(page_link)

    if not page_soup:
        print(f"Error scraping page {page_count}. Skipping...")
        continue  # Skip this page if there's an error.

    items = page_soup.find_all("div", class_="media-post-item")
    for item in items:
        date = item.find("p", class_="media-post-date").text.strip()
        title_tag = item.find("a", class_="media-post-title")
        title = title_tag.text.strip()
        link = title_tag["href"]

        print(f"Scraping speech '{title}'...")
        speech_soup = get_soup(link)

        if not speech_soup:
            print(f"Error scraping speech '{title}'. Skipping...")
            continue

        content = speech_soup.find("div", class_="media-post-page-content").text.strip()

        speeches.append(
            {
                "title": title,
                "link": link,
                "date": date,
                "content": content,
            }
        )

    pagination = page_soup.find_all("a", class_="page-link")
    next_links = [link for link in pagination if link.text == "Next →"]
    page_link = next_links[0]["href"] if next_links else None

    page_count += 1
# Out:
# Scraping page 1...
# Scraping speech 'ISO Recertification of the Office of the Vice President'...
# Scraping speech 'VPSD Speech on Go Negosyo's 18th anniversary'...
# Scraping speech 'VPSD Speech for National Children's Month Culminating Activity'...
# Scraping speech 'VPSD Speech for the Gift-Giving in Binalonan'...
# Scraping speech 'VP Sara speech for the Renaming of Agham Road and BIR Road to Senator Miriam P. Defensor-Santiago Avenue'...
# Scraping speech 'VPSD Speech During the Signing Ceremony for the Records of Discussion of the JICA-assisted Formulation of the Comprehensive and Sustainable Urban Development Masterplan for Metropolitan Davao'...
# Scraping speech 'VPSD Speech for 18th PSECE'...
# Scraping speech 'VPSD Speech for the 49th Philippine Business Conference and Expo'...
# Scraping speech 'VPSD Speech for Public Attorney’s Office 5th National Convention for the Rank-and-File Employee'...
# Scraping speech 'VPSD Speech for the 2023 National Literacy Conference'...
# Scraping page 2...
# Scraping speech 'VPSD Speech for the Supreme Court of the Philippines - Philippine Trial Judges League Inc. 30th Pearl Anniversary'...
# Scraping speech 'VPSD Speech for University of Perpetual Help System DALTA's 44th Commencement Exercises'...
# Scraping speech 'Vice President and Philippine Education Secretary Sara Z. Duterte’s Keynote Speech for the 2023 GEIS'...
# Scraping speech 'VPSD Speech for National Teacher’s Month Kick-Off'...
# Scraping speech 'VPSD Speech for the Opening of the Philippine Book Festival, SMX Convention Center, SM Davao'...
# Scraping speech 'VPSD Speech for the ALSWDOPI 26th National Convention and General Assembly'...
# Scraping speech 'VPSD Speech for the Launch of the MATATAG K to 10 Curriculum'...
# Scraping speech 'VPSD Speech for Palarong Pambansa Closing Ceremony'...
# Scraping speech 'VPSD Speech for OVP Pride Reception'...
# Scraping speech 'VPSD Speech for Insurgency-Free Davao City First Anniversary Celebration, Rizal Park, Davao City'...
# Scraping page 3...
# Scraping speech 'VPSD Speech for DepEd Language and Inclusion Summit at Marriot Hotel, Pasay City'...
# Scraping speech 'VPSD Speech for Boy Scouts of the Philippines 66th Annual National Council Meeting (ANCM)'...
# Scraping speech 'VP Sara Duterte's Message during the NTF-ELCAC Execom Meeting'...
# Scraping speech 'VPSD Speech for Santa Maria, Laguna’s Marilag Festival'...
# Scraping speech 'VPSD Video Message for Ramadan'...
# Scraping speech 'VPSD Speech for the National Election Summit, Sofitel Philippine Plaza'...
# Scraping speech 'VPSD Speech for the International Women's Day and National Women's Month Philippine Commission on Women'...
# Scraping speech 'Speech for Fraternal Order of Eagles- Philippine Eagles, Inc. Induction of New Club Members and Creation of Lady Eagles Club of Davao Prime Builders Tagatugon Eagles Club of Davao Region VII'...
# Scraping speech '2023 League of Municipalities of the Philippines (LMP) General Assembly'...
# Scraping speech 'VPSD Speech for Mindanao Development Authority (MinDa) 13th Founding Anniversary'...
# Scraping page 4...
# Scraping speech 'VPSD Speech for Kalinga 28th Founding Anniversary and 4th Bodong Festival'...
# Scraping speech 'Welcome Speech for the Opening Ceremony of the 52ND SEAMEO Council Conference'...
# Scraping speech 'Basic Education Report 2023 Speech'...
# Scraping speech 'VPSD Speech for Davao Regional Medical Center and Resident Physician Association Commencement Ceremony, Tagum City Historical and Cultural Center'...
# Scraping speech 'Vice President Duterte's Speech at the Knights of Rizal/ National Rizal Youth Leadership Institute 60th Anniversary'...
# Scraping speech 'Speech for National Children’s Day Launch of Learner Rights and Protection Office, Website and Learners TeleSafe Contact Center Helpline'...
# Scraping speech 'Speech for the Annual National Congress 2022 Philippine Librarians Association, Inc. (PLAI)'...
# Scraping speech 'Message for the Annual Kusog Mindanaw Conference 2022 Kusog Mindanaw'...
# Scraping speech 'Speech of Vice President Sara Duterte for Naval Special Operations Command 66th Founding Anniversary'...
# Scraping speech 'Speech of Vice President Sara Duterte for National Library of the Philippines 32nd Library and Information Services Month (LISM) Opening Ceremonies'...
# Scraping page 5...
# Scraping speech 'VPSD Speech for the Pastors’ Congress Jesus is Lord Church'...
# Scraping speech 'Speech of Vice President Sara Duterte for the 48th Philippine Business Conference and Expo Philippine Chamber of Commerce and Industries Fiesta Pavilion, Manila Hotel'...
# Scraping speech 'VPSD Speech for the 7th Mandatory Continuing Legal Education (MCLE) Convention for Public Attorneys'...
# Scraping speech 'VPSD Speech for Gawad Karangalan ng Lungsod ng Dasmariñas'...
# Scraping speech 'VPSD Speech for Gentrimed Heroes Movement Inc.'...
# Scraping speech 'Speech Delivered by VP Sara Duterte in Siquijor for the 50th Founding Anniversary of the Island Town'...
# Scraping speech 'VPSD Message for Province of Cotabato 108th Founding Anniversary (Kalivungan 2022)'...
# Scraping speech 'VPSD Speech for the 55th Founding Anniversary of the Association of Southeast Asian Nations (ASEAN)'...
# Scraping speech 'Speech for the Launching of OVP Buses'...
# Scraping speech 'VPSD Speech for Brigada Eskwela Kick-Off in Imus, Cavite'...
# Scraping page 6...
# Scraping speech 'VP Keynote Speech for 168th Founding Anniversary Province of Bohol'...
# Scraping speech 'VP Response To Private Educational Associations And Closing Remarks Virtual Meeting'...
# Scraping speech 'Pasasalamat at Pagpupugay'...
# Scraping speech 'Inaugural Speech of Vice President-Elect Sara Duterte'...

# %%
with open("speeches.json", "w") as f:
    json.dump(speeches, f, indent=4)
